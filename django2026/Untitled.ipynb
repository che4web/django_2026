# %%
import os
import django
os.environ.setdefault("DJANGO_SETTINGS_MODULE","django2026.settings")
django.setup()

# %%
from urlshortapp.models import ShortUrl

# %%
u = ShortUrl.objects.filter(source_url__icontains="1")

# %%
async for x in u:
    print(x.source_url)
# Out:
# 213
# 123
# 1

# %%
x.short_url =" new url"
await x.asave()

# %%
x.pk=None
await x.asave()
print(x)
# Out:
# ShortUrl object (9)

# %%
await ShortUrl.objects.filter(source_url="").exists()
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 await ShortUrl.objects.filter(source_url="").exists()
#
# File ~/web/django_2026/.venv/lib/python3.12/site-packages/django/db/models/query.py:1337, in QuerySet.exists(self)
#    1333 """
#    1334 Return True if the QuerySet would have any results, False otherwise.
#    1335 """
#    1336 if self._result_cache is None:
# -> 1337     return self.query.has_results(using=self.db)
#    1338 return bool(self._result_cache)
#
# File ~/web/django_2026/.venv/lib/python3.12/site-packages/django/db/models/sql/query.py:686, in Query.has_results(self, using)
#     684 q = self.exists()
#     685 compiler = q.get_compiler(using=using)
# --> 686 return compiler.has_results()
#
# File ~/web/django_2026/.venv/lib/python3.12/site-packages/django/db/models/sql/compiler.py:1592, in SQLCompiler.has_results(self)
# ...
